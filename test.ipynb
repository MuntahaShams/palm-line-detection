# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 58.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 725.5/725.5 kB 57.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 148.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 28.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 39.7 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 105.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 80.3 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 34.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 138.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 143.8 MB/s eta 0:00:0000:01
# ...

# %%
# !python palm_reader_pipeline.py
# Out:
# Download failed: An error occurred (403) when calling the HeadObject operation: Forbidden
# Pipeline failed: An error occurred (403) when calling the HeadObject operation: Forbidden
# Traceback (most recent call last):
#   File "/home/ec2-user/SageMaker/palm_reader_pipeline.py", line 532, in <module>
#     results = process_palm_image(s3_image_path)
#   File "/home/ec2-user/SageMaker/palm_reader_pipeline.py", line 30, in process_palm_image
#     img_path = download_from_s3(s3_image_path, tmpdir)
#   File "/home/ec2-user/SageMaker/palm_reader_pipeline.py", line 58, in download_from_s3
#     s3.download_file(bucket, key, local_path)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/botocore/context.py", line 123, in wrapper
#     return func(*args, **kwargs)
#   File "/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/boto3/s3/inject.py", line 223, in download_file
#     return transfer.download_file(
# ...
